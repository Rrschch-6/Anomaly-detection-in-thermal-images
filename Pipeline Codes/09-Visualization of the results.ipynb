# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import auc

#Models
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing



#Sampling Libraries
from imblearn.over_sampling import SMOTE 

#Imputation Libraries
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#Data
from sklearn.datasets import load_boston

#Costant Value
from sklearn.feature_selection import VarianceThreshold

#Encoding Libraries
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
import keras
import tensorflow as tf
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape
#from keras.layers import BatchNormalization
from keras.models import Model
from keras.datasets import mnist
from keras import backend as K
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import datetime
import seaborn as sns

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94716/Report Data
# Out:
# /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94716/Report Data

# %%
tpr_94716=np.load("tpr_94716.npy")
fpr_94716=np.load("fpr_94716.npy")
tpr_kde_94716=np.load("tpr_kde_94716.npy")
fpr_kde_94716=np.load("fpr_kde_94716.npy")
df=pd.read_excel('94716_measures_of accuracy.xlsx')
auc_94716=df.loc[0][5]
df=pd.read_excel('94716_kde_measures_of accuracy.xlsx')
auc_kde_94716=df.loc[0][5]

# %%
# %cd /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94706/Report Data
# Out:
# /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94706/Report Data

# %%
tpr_94706=np.load("tpr_94706.npy")
fpr_94706=np.load("fpr_94706.npy")
tpr_kde_94706=np.load("tpr_kde_94706.npy")
fpr_kde_94706=np.load("fpr_kde_94706.npy")
df=pd.read_excel('94706_measures_of accuracy.xlsx')
auc_94706=df.loc[0][5]
df=pd.read_excel('94706_kde_measures_of accuracy.xlsx')
auc_kde_94706=df.loc[0][5]

# %%
# %cd /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94693/Report Data
# Out:
# /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94693/Report Data

# %%
tpr_94693=np.load("tpr_94693.npy")
fpr_94693=np.load("fpr_94693.npy")
tpr_kde_94693=np.load("tpr_kde_94693.npy")
fpr_kde_94693=np.load("fpr_kde_94693.npy")
df=pd.read_excel('94693_measures_of accuracy.xlsx')
auc_94693=df.loc[0][5]
df=pd.read_excel('94693_kde_measures_of accuracy.xlsx')
auc_kde_94693=df.loc[0][5]

# %%
# %cd /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94689/Report Data
# Out:
# /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/94689/Report Data

# %%
tpr_94689=np.load("tpr_94689.npy")
fpr_94689=np.load("fpr_94689.npy")
tpr_kde_94689=np.load("tpr_kde_94689.npy")
fpr_kde_94689=np.load("fpr_kde_94689.npy")
df=pd.read_excel('94689_measures_of accuracy.xlsx')
auc_94689=df.loc[0][5]
df=pd.read_excel('94689_kde_measures_of accuracy.xlsx')
auc_kde_94689=df.loc[0][5]

# %%
# %cd /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/Report Data
# Out:
# /content/drive/My Drive/SRH Heidelberg/Case Study 1/Codes-Sasha/00-Data/thermal_images/Report Data

# %%
plt.figure(figsize=(5,4), dpi=80)
plt.xlabel("FPR", fontsize=14)
plt.ylabel("TPR", fontsize=14)


plt.plot(fpr_94716,tpr_94716,color='blue', linewidth=2, label=f"94716 - AUC {round(auc_94716,2)}")
plt.plot(fpr_94706,tpr_94706,color='red', linewidth=2, label=f"94706 - AUC {round(auc_94706,2)}")
plt.plot(fpr_94693,tpr_94693,color='green', linewidth=2, label=f"94693 - AUC {round(auc_94693,2)}")
plt.plot(fpr_94689,tpr_94689,color='orange', linewidth=2, label=f"94689- AUC {round(auc_94689,2)}")

if True:
        x = [0.0, 1.0]
        plt.plot(x, x, linestyle='dashed', color='red', linewidth=2, label='random TPR=FPR')
ax = plt.axes()
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.legend(fontsize=10, loc='lower right')
plt.tight_layout()
plt.savefig('AE_ROC.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.figure(figsize=(5,4), dpi=80)
plt.xlabel("FPR", fontsize=14)
plt.ylabel("TPR", fontsize=14)


plt.plot(fpr_kde_94716,tpr_kde_94716,color='blue', linewidth=2, label=f"94716 - AUC {round(auc_kde_94716,2)}")
plt.plot(fpr_kde_94706,tpr_kde_94706,color='red', linewidth=2, label=f"94706 - AUC {round(auc_kde_94706,2)}")
plt.plot(fpr_kde_94693,tpr_kde_94693,color='green', linewidth=2, label=f"94693 - AUC {round(auc_kde_94693,2)}")
plt.plot(fpr_kde_94689,tpr_kde_94689,color='orange', linewidth=2, label=f"94689- AUC {round(auc_kde_94689,2)}")

if True:
        x = [0.0, 1.0]
        plt.plot(x, x, linestyle='dashed', color='red', linewidth=2, label='random TPR=FPR')
ax = plt.axes()
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.legend(fontsize=10, loc='best')
plt.tight_layout()
plt.savefig('AE_kde_ROC.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
